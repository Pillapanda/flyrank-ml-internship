# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Pillapanda/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
print("""I chose the Refresh / Content Opportunity Scoring lane because the starter dataset contains search visibility, clicks, sessions, CTR, content age, freshness, position, and engagement signals. These signals can help prioritize which pages deserve human review rather than treating every page equally.""")
# Out:
# I chose the Refresh / Content Opportunity Scoring lane because the starter dataset contains search visibility, clicks, sessions, CTR, content age, freshness, position, and engagement signals. These signals can help prioritize which pages deserve human review rather than treating every page equally.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
print("""Decision: The work improves the decision of whether a location should be flagged for potential water-borne disease risk and prioritized for further investigation.

Who acts: Public-health officials and field health workers act on the recommendation by conducting additional testing, investigating the location, and deploying preventive measures when necessary.

Cost of a wrong call: A false positive can waste limited field-testing resources and personnel by investigating low-risk locations. A false negative is more costly because it can delay intervention during a genuine outbreak, potentially increasing the number of affected people. Therefore, the model should prioritize reducing false negatives while maintaining a manageable false-positive rate.""")
# Out:
# Decision: The work improves the decision of whether a location should be flagged for potential water-borne disease risk and prioritized for further investigation.
#
# Who acts: Public-health officials and field health workers act on the recommendation by conducting additional testing, investigating the location, and deploying preventive measures when necessary.
#
# Cost of a wrong call: A false positive can waste limited field-testing resources and personnel by investigating low-risk locations. A false negative is more costly because it can delay intervention during a genuine outbreak, potentially increasing the number of affected people. Therefore, the model should prioritize reducing false negatives while maintaining a manageable false-positive rate.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
print("""Quick data check: The starter dataset contains X observations across Y features. The target variable contains X% positive/high-risk cases, meaning both classes are represented sufficiently for classification. In addition, [feature] ranges from X to Y, showing meaningful variation that could potentially help distinguish high-risk from low-risk observations. These initial statistics suggest that the dataset contains enough variation and a meaningful prediction target to investigate this lane over the next seven weeks.""")
# Out:
# Quick data check: The starter dataset contains X observations across Y features. The target variable contains X% positive/high-risk cases, meaning both classes are represented sufficiently for classification. In addition, [feature] ranges from X to Y, showing meaningful variation that could potentially help distinguish high-risk from low-risk observations. These initial statistics suggest that the dataset contains enough variation and a meaningful prediction target to investigate this lane over the next seven weeks.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
print("""What the work can say: The analysis can identify observed patterns in the available data and provide directional estimates of which locations or conditions are associated with higher disease risk. The resulting model can be used as decision support to help health officials prioritize locations for further monitoring, testing, or investigation.

What the work cannot say: The analysis cannot establish causal relationships between environmental factors and disease occurrence. It cannot guarantee that a predicted high-risk location will experience an outbreak, nor can it claim to predict outbreaks with certainty. The model is intended to support human decision-making rather than replace laboratory testing, epidemiological investigation, or expert judgment.""")
# Out:
# What the work can say: The analysis can identify observed patterns in the available data and provide directional estimates of which locations or conditions are associated with higher disease risk. The resulting model can be used as decision support to help health officials prioritize locations for further monitoring, testing, or investigation.
#
# What the work cannot say: The analysis cannot establish causal relationships between environmental factors and disease occurrence. It cannot guarantee that a predicted high-risk location will experience an outbreak, nor can it claim to predict outbreaks with certainty. The model is intended to support human decision-making rather than replace laboratory testing, epidemiological investigation, or expert judgment.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
